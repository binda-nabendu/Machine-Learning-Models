# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('meterial\\hotel_booking_short_list.csv', index_col= 0)

# %%
# df1.reset_index(inplace=True)

# %%
df1.head()
# Out:
#        is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# index
# 0                0        342               2015                        27
# 1                0        737               2015                        27
# 2                0          7               2015                        27
# 3                0         13               2015                        27
# 4                0         14               2015                        27
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# index
# 0                              1                        0
# 1                              1                        0
# 2                              1                        0
# 3                              1                        0
# 4                              1                        0
#
#        stays_in_week_nights  adults  children
# index
# 0                         0       2         0
# 1                         0       2         0
# ...

# %%
df1['lead_time'].hist()
# Out:
# <Axes: >

# %%
df1['lead_time'].hist(bins = 100)
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
df1['lead_time'].hist(bins = 100)
# Out:
# <Axes: >

# %%
df1['lead_time'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['lead_time'].plot(kind = 'hist', bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.area() # it will work with only integer values
# Out:
# <Axes: xlabel='index'>

# %%
df1.plot.area(alpha = .4)
# Out:
# <Axes: xlabel='index'>

# %%
df1.plot.bar()
# Out:
# <Axes: xlabel='index'>

# %%
df1.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='index'>

# %%
df1.plot.bar(stacked=True, figsize = (22, 3))
# Out:
# <Axes: xlabel='index'>

# %%
df1.plot.line(y = 'is_canceled', figsize = (12, 3))
# Out:
# <Axes: xlabel='index'>

# %%
df1.columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults',
#        'children'],
#       dtype='object')

# %%
from numpy.random import randn

# %%
df2 = pd.DataFrame(randn(5, 4), ['A','B', 'C', 'D', 'E'], ['W', 'X', 'Y', 'Z'])

# %%
df1.plot.scatter(x='is_canceled', y = 'arrival_date_year')
# Out:
# <Axes: xlabel='is_canceled', ylabel='arrival_date_year'>

# %%
df2.plot.scatter(x='W', y = 'X', c = 'green')
# Out:
# <Axes: xlabel='W', ylabel='X'>

# %%
df2.plot.scatter(x='W', y = 'X', cmap = 'coolwarm')
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\pandas\plotting\_matplotlib\core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df3 = pd.DataFrame(randn(1000, 2), columns=['A', 'B'])

# %%
df3.head()
# Out:
#           A         B
# 0  0.291298 -0.186406
# 1 -0.834252  1.552245
# 2  2.294245 -0.763631
# 3 -0.978082 -0.797777
# 4  1.739209  0.368020

# %%
df3.plot.scatter(x='A', y = 'B', cmap = 'coolwarm')
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\pandas\plotting\_matplotlib\core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %%
df3.plot.hexbin(x='A', y = 'B', gridsize=50, cmap = 'coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df3['A'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df3.plot.density()
# Out:
# <Axes: ylabel='Density'>
