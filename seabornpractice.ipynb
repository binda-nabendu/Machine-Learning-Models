# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips['total_bill']) #Relative frequency distribution: provide percentage
# Out:
# C:\Users\Nabendu\AppData\Local\Temp\ipykernel_7592\2114960246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill']) #Relative frequency distribution: provide percentage
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(tips['total_bill'], kde = True) #Regular frequency distribution: provide count
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(tips['total_bill'], kde = False)
# Out:
# C:\Users\Nabendu\AppData\Local\Temp\ipykernel_7592\2150339336.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde = False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'], kde = False, bins= 30)
# Out:
# C:\Users\Nabendu\AppData\Local\Temp\ipykernel_7592\2836406886.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde = False, bins= 30)
# <Axes: xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill', y = 'tip', data=tips)

# %%
sns.jointplot(x='total_bill', y = 'tip', data=tips, kind='hex', gridsize = 40)

# %%
sns.jointplot(x='total_bill', y = 'tip', data=tips, kind='reg') #kind= 'reg' means regression

# %%
import matplotlib.pyplot as plt

# %%
sns.jointplot(x='total_bill', y = 'tip', data=tips, kind='kde', palette=['red', 'green', 'blue'])
plt.show()

# %%
sns.jointplot(x='total_bill', y = 'tip', data=tips, kind='kde', palette=['red', 'green', 'blue'], fill = 'True')
plt.show()

# %%
sns.pairplot(tips)
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips, hue = 'day')# hue parameter categorized depend on provided column name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.pairplot(tips, hue = 'day')
#
# NameError: name 'sns' is not defined

# %%
sns.pairplot(tips)
sns.pairplot(tips, hue='sex', palette = ['red', 'green', 'blue'])
plt.show()
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# ...

# %%
sns.pairplot(tips)
sns.pairplot(tips,vars = ['tip', 'size'], hue='sex', palette = ['red', 'green', 'blue'], diag_kind = 'hist')
plt.show()
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=vector, **plot_kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   func(x=x, y=y, **kwargs)
# ...

# %%
sns.pairplot(tips)
sns.pairplot(tips,vars= ['total_bill', 'size'], hue='sex', palette = ['red', 'green'])
plt.show()
# Out:
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Nabendu\anaconda3\envs\notebooktask\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Nabendu\AppData\Local\Temp\ipykernel_7592\2220850445.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
sns.rugplot(data = tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(data = tips, x = 'size', y = 'total_bill', hue = 'sex')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
#  Catagorical Data plotting

# %%
sns.rugplot(data = tips, x = 'size', y = 'total_bill', hue = 'sex', height = .3)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
plt.figure(figsize=(15, 7))
sns.rugplot(data = tips, x = 'size', y = 'total_bill', hue = 'sex', height = .3)
sns.distplot(tips['total_bill'], kde = False, bins= 30)
# Out:
# C:\Users\Nabendu\AppData\Local\Temp\ipykernel_7592\655390733.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde = False, bins= 30)
# <Axes: xlabel='total_bill', ylabel='total_bill'>

# %%
sns.barplot(x= 'sex', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
sns.barplot(x= 'sex', y = 'total_bill', data = tips, estimator= np.std)#default estimator = mean
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'smoker' , palette= ['r', 'g'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y = 'total_bill', data = tips, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y = 'total_bill', data = tips, hue = 'sex', split= True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y = 'total_bill', data= tips) # can say categorical scatter plot
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y = 'total_bill', data= tips, jitter = False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y = 'total_bill', data= tips, jitter = True, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y = 'total_bill', data= tips, jitter = True, hue = 'sex', dodge = True) # 'split' work like 'dodge'
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data = tips)
sns.swarmplot(x='day', y='total_bill', data = tips, color='yellow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
